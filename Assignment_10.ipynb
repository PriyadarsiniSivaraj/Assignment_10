# %%
# Q1.

import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize

#Given temperature ranges
Max = np.array([39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25])
Min = np.array([21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18])
months = np.arange(12)

#Defining the periodic function with noise
def periodic_func(times, avg, ampl, time_offset):
    return (avg
            + ampl * np.cos((times + time_offset) * 2 * np.pi / times.max()))

#Fitting the data to the periodic function
res_max, cov_max = optimize.curve_fit(periodic_func, months,Max,[20, 10, 0])
res_min, cov_min = optimize.curve_fit(periodic_func, months,Min,[-40, 20, 0])

days = np.linspace(0, 12, num=365)

#Plotting the fit
plt.figure()
plt.plot(months, Max, 'ro')
plt.plot(days, periodic_func(days, *res_max), 'r-')
plt.plot(months, Min, 'bo')
plt.plot(days, periodic_func(days, *res_min), 'b-')
plt.xlabel('Month')
plt.ylabel('Temperature ($^\circ$C)')

plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
# Q2.1 Create a pie chart presenting the male/female proportion
import pandas as pd
url ='https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv' 
titanic = pd.read_csv(url)
#titanic.head()
titanic['sex'].value_counts().plot(kind='pie')

# %%
# Q2.2 Create a scatterplot with the Fare paid and the Age, differ the plot color by gender

plt.scatter(titanic.fare,titanic.age ,c=np.where(titanic.sex=='female','r','b'))
plt.xlabel('Fare')
plt.ylabel('Age')
plt.legend(titanic.sex)
